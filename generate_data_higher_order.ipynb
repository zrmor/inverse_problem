# %%
import pandas as pd
import numpy as np
from functions import *

# %%
sum = 0
for i in range(50000000):
    sum+=i

# %%
gamma_var_min, gamma_var_max = 0.1, 1
gamma_mean_min, gamma_mean_max = 0.1, 1
size = 30

generate_data_higher_order(gamma_var_min, gamma_var_max,
                           gamma_mean_min, gamma_mean_max,
                           size)
