# %%
import pandas as pd
import numpy as np
from functions import *

# %%
sum = 0
for i in range(50000000):
    sum+=i

# %%
min_var_J, max_var_J = 1, 2
min_mean_J, max_mean_J = 1, 2
size = 30
generate_data_higher_variance(min_var_J, max_var_J,
                                min_mean_J, max_mean_J,
                                size)
